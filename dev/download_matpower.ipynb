# %%
import os
import sys

# add parent directory to path to import matpowerpip without installation
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

print(f"Added to path: {parent_dir}")

# %%
from matpowerpip.downloader import copy_init, download_matpower

# %%
download_matpower(matpower_version="8.1", force=True, backup="../backups")
copy_init()

# %%
download_matpower(matpower_version="master", force=True, backup="../backups")
copy_init()
